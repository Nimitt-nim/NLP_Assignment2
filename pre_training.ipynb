# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from transformers import AutoModelForCausalLM, GemmaConfig, AutoTokenizer, AutoModel, MistralConfig, MistralModel, MistralForCausalLM, LlamaConfig, LlamaForCausalLM
import torch
import torch.nn as nn
import torch.nn.init as init
import json
import pickle
import pandas as pd

# %% [markdown]
# ### Code 1

# %%
tokenizer = AutoTokenizer.from_pretrained("/content/drive/MyDrive/NLP/tokenizer1")

# %%
len(tokenizer.vocab)
# Out:
# 32769

# %%
config = LlamaConfig(hidden_size=512,
                     vocab_size=32769,
                     num_attention_heads=8,
                     num_key_value_heads=2,
                     num_hidden_layers=24,
                     intermediate_size=1024,
                     max_position_embeddings=512)
config
# Out:
# LlamaConfig {
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "head_dim": 64,
#   "hidden_act": "silu",
#   "hidden_size": 512,
#   "initializer_range": 0.02,
#   "intermediate_size": 1024,
#   "max_position_embeddings": 512,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 8,
#   "num_hidden_layers": 24,
#   "num_key_value_heads": 2,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": null,
#   "rope_theta": 10000.0,
#   "tie_word_embeddings": false,
#   "transformers_version": "4.46.2",
#   "use_cache": true,
#   "vocab_size": 32769
# }

# %%
model_mis = LlamaForCausalLM(config)

# %%
for i,j in model_mis.named_parameters():
  if j.requires_grad and len(j.size()) > 1:
    init.xavier_uniform_(j.data)

# %%
total_param=0
for i,j in model_mis.named_parameters():
    total_param += j.numel()
print(total_param/(10**6))

# %%
model_mis.save_pretrained("/content/drive/MyDrive/NLP/model1")
tokenizer.save_pretrained("/content/drive/MyDrive/NLP/model1")
# Out:
# ('/content/drive/MyDrive/NLP/model1/tokenizer_config.json',
#  '/content/drive/MyDrive/NLP/model1/special_tokens_map.json',
#  '/content/drive/MyDrive/NLP/model1/tokenizer.json')

# %% [markdown]
# ### Code 2

# %%
# %pip install datasets

# %%
from datasets import Dataset, DatasetDict
from datasets import load_dataset
import pandas as pd

# %% [markdown]
# ### Code 3

# %%
from transformers import AutoTokenizer, DataCollatorForLanguageModeling
from datasets import Dataset

# Tokenizer setup
tokenizer = AutoTokenizer.from_pretrained("/content/drive/MyDrive/NLP/tokenizer1")

# Load data and add <eos>
df = pd.read_csv("/content/drive/MyDrive/NLP/bengali_dataset_0.5.csv")
df["text"] = df["Input"] + "<eos>"

# Convert to Hugging Face dataset
dataset = Dataset.from_pandas(df)

# Tokenize with padding, truncation, and labels
def tokenize_function(examples):
    return tokenizer(
        examples["text"],
        padding="max_length",
        truncation=True,
        max_length=512,
        return_tensors="pt"
    )

tokenized_dataset = dataset.map(tokenize_function, batched=True)

# Split dataset
split_dataset = tokenized_dataset.train_test_split(test_size=0.1)
train_dataset = split_dataset["train"]
eval_dataset = split_dataset["test"]

# Data collator for batching
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False
)
# Out:
# Map:   0%|          | 0/429533 [00:00<?, ? examples/s]

# %%
from transformers import Trainer, TrainingArguments

# %%
# %pip install -q bitsandbytes trl peft -U
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.9/310.9 kB 21.4 MB/s eta 0:00:00

# %%
training_args = TrainingArguments(
    output_dir="/content/drive/MyDrive/NLP//model1",
    overwrite_output_dir=True,
    num_train_epochs=50,
    logging_steps=10,
    learning_rate=2e-3,
    bf16=True,
    do_train=True,
    per_device_train_batch_size=8,
    save_steps=500,
    save_total_limit=2,
    report_to="none",
)

# %%
# Trainer initialization
trainer = Trainer(
    model=model_mis,  # Your model
    args=training_args,
    train_dataset=train_dataset,  # Tokenized training dataset
    eval_dataset=eval_dataset,  # Tokenized evaluation dataset
    tokenizer=tokenizer,  # Tokenizer for padding, decoding, etc.
    data_collator=data_collator,  # Handles batching
)
# Out:
# <ipython-input-44-5fba12d6e387>:2: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
tokenizer.pad_token = tokenizer.eos_token

# %%
import sys

# Redirect stdout to a file
log_file = open("/content/drive/MyDrive/NLP/training_log.txt", "w")
sys.stdout = log_file

trainer.train()

# Close the log file
log_file.close()

# Reset stdout to default
sys.stdout = sys.__stdout__
# Out:
#     <div>
#
#       <progress value='4287' max='2416150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   4287/2416150 1:18:28 < 736:13:00, 0.91 it/s, Epoch 0.09/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>4.753400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.143400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.538100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.488000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.226500</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.424500</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.736400</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.315800</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.923400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.957600</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.232200</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.547200</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>1.422100</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>1.769900</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.257300</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>1.654300</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>1.469600</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>1.148800</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>1.872000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.144700</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>1.533600</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>1.075600</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>1.696300</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>1.666700</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.449800</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>1.425700</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>1.354100</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.999800</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>1.396100</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.393500</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>1.143300</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>1.297900</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>1.725800</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>1.075300</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.064900</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>1.594700</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>1.209200</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>1.348000</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.983600</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.136500</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>1.322200</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>1.534700</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>1.455300</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>1.525300</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.223900</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.957400</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>1.367900</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>1.568000</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.949200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.156600</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>1.704600</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>1.324500</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>1.190200</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.985300</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>1.201200</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>1.214200</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>1.485600</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>1.474800</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>1.012600</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.247900</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>1.324000</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>1.579600</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>1.364600</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>1.207500</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.877500</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>1.194900</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.966800</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>1.380300</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>1.156000</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.944600</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>1.015400</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>1.731400</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>1.159400</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>1.667300</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>1.153600</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>1.234700</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>1.266200</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>1.217700</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.960400</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.239000</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>1.176900</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>1.185000</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>1.450800</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>1.044800</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.806900</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>1.277500</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>1.161300</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>1.542200</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>1.109500</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.139900</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>0.988900</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>1.014200</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>1.592300</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.940800</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>1.689500</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>1.298100</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>1.018100</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>1.294100</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>1.331300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.474400</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>1.377000</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>1.608700</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>1.202100</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>1.222000</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>1.249400</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>1.441000</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>1.142800</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>1.413200</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>1.383200</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.963400</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>0.995600</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>1.486600</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>0.976700</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>1.179600</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>1.403000</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>1.388500</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>1.077900</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>1.225400</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>1.209600</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.098400</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>1.371300</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>1.173200</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>1.365000
#     <div>
#
#       <progress value='7722' max='2416150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   7722/2416150 2:22:08 < 739:05:19, 0.91 it/s, Epoch 0.16/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>4.753400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.143400</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.538100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.488000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.226500</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.424500</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.736400</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.315800</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.923400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.957600</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.232200</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.547200</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>1.422100</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>1.769900</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.257300</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>1.654300</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>1.469600</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>1.148800</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>1.872000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.144700</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>1.533600</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>1.075600</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>1.696300</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>1.666700</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.449800</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>1.425700</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>1.354100</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.999800</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>1.396100</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.393500</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>1.143300</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>1.297900</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>1.725800</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>1.075300</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.064900</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>1.594700</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>1.209200</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>1.348000</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.983600</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.136500</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>1.322200</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>1.534700</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>1.455300</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>1.525300</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.223900</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.957400</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>1.367900</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>1.568000</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.949200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.156600</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>1.704600</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>1.324500</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>1.190200</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.985300</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>1.201200</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>1.214200</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>1.485600</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>1.474800</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>1.012600</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.247900</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>1.324000</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>1.579600</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>1.364600</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>1.207500</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.877500</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>1.194900</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.966800</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>1.380300</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>1.156000</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.944600</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>1.015400</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>1.731400</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>1.159400</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>1.667300</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>1.153600</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>1.234700</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>1.266200</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>1.217700</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.960400</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.239000</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>1.176900</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>1.185000</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>1.450800</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>1.044800</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.806900</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>1.277500</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>1.161300</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>1.542200</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>1.109500</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>1.139900</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>0.988900</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>1.014200</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>1.592300</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.940800</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>1.689500</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>1.298100</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>1.018100</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>1.294100</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>1.331300</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.474400</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>1.377000</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>1.608700</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>1.202100</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>1.222000</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>1.249400</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>1.441000</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>1.142800</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>1.413200</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>1.383200</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.963400</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>0.995600</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>1.486600</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>0.976700</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>1.179600</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>1.403000</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>1.388500</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>1.077900</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>1.225400</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>1.209600</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>1.098400</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>1.371300</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>1.173200</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>1.365000

# %%
custom_input = "উন্নয়নে সিংড়া রাতে প্রায় ৫১লাখ টাকা ব্যয়ে নাটোর-বড়া মহাসড়কের শেরকোল হইতে"
input_dict = {'text': [custom_input]}

# %%
input_dict = {'input_ids': [tokenizer.encode(custom_input)]}
input_dict
# Out:
# {'input_ids': [[5795,
#    3754,
#    368,
#    1704,
#    1353,
#    12449,
#    136,
#    48,
#    1162,
#    10228,
#    14563,
#    3815,
#    368,
#    11542,
#    10387,
#    47,
#    629,
#    15920]]}

# %%
custom_dataset = Dataset.from_dict(input_dict)

# %%
predictions = trainer.predict(custom_dataset)
# Out:
#     <div>
#
#       <progress value='897' max='2416150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [    897/2416150 16:08 < 726:02:54, 0.92 it/s, Epoch 0.02/50]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.393500</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.589200</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.243500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.276900</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.041500</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.149500</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.435100</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.134300</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.710700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.757200</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.148800</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.441900</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>1.300100</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>1.643900</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.154400</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>1.528600</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>1.377200</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>1.054800</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>1.699500</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.052800</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>1.437900</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>1.042800</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>1.668400</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>1.643200</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>1.414000</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>1.391700</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>1.331300</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.963900</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>1.387800</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.384300</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>1.132600</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>1.284300</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>1.704100</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>1.064700</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.048900</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>1.601600</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>1.170800</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>1.308600</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.976000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.135800</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>1.318900</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>1.549300</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>1.476600</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>1.713800</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.263000</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.973800</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>1.372700</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>1.575800</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.941700</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.143800</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>1.638000</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>1.306600</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>1.172400</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.974100</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>1.188600</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>1.215700</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>1.500300</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>1.483900</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>1.020300</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.263200</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>1.336900</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>1.574900</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>1.368600</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>1.257900</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.910000</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>1.228000</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.998000</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>1.403400</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>1.183100</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.959400</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>1.032000</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>1.748000</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>1.186100</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>1.682300</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>1.199500</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>1.269200</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>1.295400</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>1.241800</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.988500</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>1.282100</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>1.205400</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>1.223400</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>1.473300</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>1.028600</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.778600</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>1.252700</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>1.145100</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>1.521600</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>1.090300</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/1 : < :]
#     </div>

# %%
generated_outputs = predictions.predictions  # This will be logits

# %%
output_ids = torch.argmax(torch.tensor(generated_outputs), dim=2)

# %%
tokenizer.decode(output_ids[0])
# Out:
# ',,, ও1   ব্যবসা করে  ও  <unk> করে ও'

# %%
output_ids
# Out:
# tensor([[118, 118,  22,  22, 118,  22, 118, 118, 118,  22, 118,  22,  22,  22,
#           22,  22,  22,   1]])

# %%
trainer.save_model("/content/drive/MyDrive/NLP/trained_model1")
tokenizer.save_pretrained("/content/drive/MyDrive/NLP/trained_model1")
# Out:
# ('/content/drive/MyDrive/NLP/trained_model1/tokenizer_config.json',
#  '/content/drive/MyDrive/NLP/trained_model1/special_tokens_map.json',
#  '/content/drive/MyDrive/NLP/trained_model1/tokenizer.json')
